# %%
from selenium import webdriver
from bs4 import BeautifulSoup
driver = webdriver.Chrome('C:/Users/ahw48/Documents/GitHub/LIKELION_CODE/Class/chromedriver_90')
url = 'https://www.amazon.com/'
driver.get(url)
sel_search = driver.find_element_by_xpath('//*[@id="twotabsearchtextbox"]')
sel_btn = driver.find_element_by_xpath('//*[@id="nav-search-submit-button"]')
sel_search.clear()
sel_search.send_keys("keyboard")
sel_btn.click()

# %%
sel_keyboard = driver.find_element_by_xpath('//*[@id="search"]/div[1]/div/div[1]/div/span[3]/div[2]/div[5]/div/span/div/div/div[2]/div[2]/div/div[1]/h2/a')
sel_keyboard.click()

# %%
sel_ratings = driver.find_element_by_xpath('//*[@id="acrCustomerReviewLink"]')
sel_ratings.click()

# %%
see_all = driver.find_element_by_xpath('//*[@id="cr-pagination-footer-0"]/a')
see_all.click()

# %%
page = driver.page_source
soup = BeautifulSoup(page,'html.parser')
soup.title
# Out:
# <title>Amazon.com: Customer reviews: Redragon S101 Wired Gaming Keyboard and Mouse Combo RGB Backlit Gaming Keyboard with Multimedia Keys Wrist Rest and Red Backlit Gaming Mouse 3200 DPI for Windows PC Gamers (Black)</title>

# %%
import pandas as pd
import time
all_reviews = []


for page in range(1, 11, 1):
    time.sleep(2)
    
    page = driver.page_source
    soup = BeautifulSoup(page,'html.parser')
    all_r = soup.findAll("div", class_="a-section celwidget")
    for one in all_r:
        user = one.find('span', class_='a-profile-name').text
        rating = one.find('span',class_='a-icon-alt').text.split()[0]
        date = one.find('span',class_='a-size-base a-color-secondary review-date').text.split('on')[-1]
        region= one.find('span', class_='a-size-base a-color-secondary review-date').text.split('on')[0]
        review = one.find('span', class_='a-size-base review-text review-text-content').text.strip()
        helpful = one.find('span', class_='a-size-base a-color-tertiary cr-vote-text')
        
        if helpful is not None:
            helpful = helpful.text.split()[0]
            if helpful == "One":
                helpful = "1"
        else:
            helpful = "0"
        
        all_reviews.append({
            "user": user,
            "rating": rating,
            "date": date,
            "region": region,
            "review": review,
            "helpful": helpful
        })
    
    sel_next = driver.find_element_by_xpath('//*[@id="cm_cr-pagination_bar"]/ul/li[2]/a')
    sel_next.click()
    
review_dat = pd.DataFrame(all_reviews)
review_dat.to_csv("amazon_reviews.csv", index=False)
review_dat
# Out:
#                    user rating                date  \
# 0       Michael D. Cole    5.0      April 10, 2018
# 1                  Kels    5.0      April 23, 2018
# 2            Jon Almada    5.0      August 4, 2018
# 3                 Shawn    5.0       July 11, 2018
# 4              Brian S.    5.0     August 25, 2018
# ..                  ...    ...                 ...
# 95  James Paul Williams    1.0      April 26, 2020
# 96     Willie V. Hughes    5.0   December 13, 2020
# 97                   jp    4.0    October 22, 2020
# 98      Amazon Customer    1.0     August 26, 2020
# 99      Kindle Customer    3.0   September 2, 2020
#
#                             region  \
# 0   Reviewed in the United States
# 1   Reviewed in the United States
# 2   Reviewed in the United States
# 3   Reviewed in the United States
# 4   Reviewed in the United States
# ..                             ...
# 95  Reviewed in the United States
# 96  Reviewed in the United States
# 97  Reviewed in the United States
# 98  Reviewed in the United States
# 99  Reviewed in the United States
#
#                                                review helpful
# 0   My job gave me a computer with a crap ass keyb...   1,152
# 1   I was looking for a keyboard/mouse set to play...     476
# 2   I bought this combination, expecting it to wor...     357
# 3   I bought this for my kid so I wasn't too conce...     162
# 4   My son wasn't enjoying my old 2005 logitech wi...     152
# ..                                                ...     ...
# 95  In the game I play, function keys are used to ...       2
# 96  I bought two of these sets during the pandemic...       0
# 97  I got my first pc a couple of months ago to st...       0
# 98  I bought this keyboard because I like the colo...       2
# 99  This keyboard/mouse was fine with me for every...       0
#
# [100 rows x 6 columns]
