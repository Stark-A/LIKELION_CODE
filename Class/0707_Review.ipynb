# %%
### 데이터 연결
 * concat
   * concat - 행으로 연결할 때, axis=0
   * concat - 열로 연결할 때, axis=1
   * 두 개의 데이터 셋을 연결할 때, 공통된 열만 가져오겠다.
     * join = 'inner'
    
### 데이터 확인
   * [].value_counts()
   * 유일한 값들만 확인하기 : unique()
   * 값을 정렬하기
     * [].sort_values(by='열이름', ascending=Fasle)
   * 값을 변경하기
     * [].replace([__,__],'rare')
    
   * 라벨 인코딩
     * 문자를 숫자로 변환
        * 왜 변환할까요? 컴퓨터, 모델이 이해할 수 있도록 변환
   * [].fillna()
     * 수치형 결측치 처리 - 평균, 중앙값
        * 평균의 단점 - 특이값(이상치)가 왜곡을 일으킬 수 있다.
          * 이상치 처리 - 없애거나, 설명 가능한 값으로 변경.
     * 범주형 결측치 처리 - 최빈값으로 처리
    
   * 데이터 형변환 함수
     * [].astype()
       * astype(str)
       * astype(int)
    
### 어떤 데이터를 그룹으로 묶어서 통계(std(), var()...)
   * [].groupby()
   * a = [].groupby([])

### 내가 원하는 컬럼을 삭제
   * [].drop.([ __, __ ], axis=1)  # axis=0 행을 삭제
    
### 통계 기본
   * 상관관계
     * 사용되는 그래프 - 산점도(scatter, plot)
       * seaborn - sns.lmplot(), sns.pairplot
   * 상관계수 값의 범위
     * -1 ~ 1
       * 절대값이 1에 가까울 수록 어떠하다?
        * 강한 상관관계를 갖는다.
       * 절대값이 0에 가까울 수록 어떠하다?
        * 상관관계가 없다. 독립적이다.

### matplotlib
   * 제목을 달아줄 때.
      * sns.boxplot()
      * plt.title()
      * x축 레이블 : plt.xlabel, plt.ylabel
   * 멀티 그래프
      * plt.subplot(행, 열, 1)
   * 범례를 달아주기
      * plt.plot(----, label="")
      * plt.legend()
        
### pandas : 데이터 처리

### matplolib, seaborn, plotly, folium : 시각화

### 수학함수, 통계, 임의의 난수 발생 : numpy

### numpy as np
 * np.array[] : numpy 배열
 * np.random.normal() : 임의의 난수 발생, 정규분포를 따르도록

### plotly 그래프를 사용하는 방법
 * cuffilinks - [].iplot()
 * plotly.express
